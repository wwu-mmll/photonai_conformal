# %% [markdown]
# # Conformal Predictions Example

# %%
import photonai_conformal
from sklearn.datasets import load_diabetes
from sklearn.model_selection import KFold
from sklearn.gaussian_process import GaussianProcessRegressor

from photonai.base import Hyperpipe, PipelineElement

# %% [markdown]
# ## Define Hyperpipe

# %%
my_pipe = Hyperpipe('conformal_pipe',
                    optimizer='random_search',
                    metrics=['mean_squared_error', 'mean_absolute_error', 'explained_variance'],
                    best_config_metric='mean_squared_error',
                    outer_cv=KFold(n_splits=3, shuffle=True),
                    inner_cv=KFold(n_splits=3, shuffle=True),
                    verbosity=1,
                    project_folder='./tmp/')

my_pipe += PipelineElement("ConformalRegressor", estimator=GaussianProcessRegressor(), alpha=[.05, .5, .95])

# %% [markdown]
# ## Load Data and fit Hyperpipe

# %%
# load data and train
X, y = load_diabetes(return_X_y=True)
my_pipe.fit(X, y)
# Out:
# 07/12/2022-15:35:42 | Output Folder: ./tmp/conformal_pipe_results_2022-12-07_15-35-42
# =====================================================================================================
# PHOTONAI ANALYSIS: conformal_pipe
# =====================================================================================================
# 07/12/2022-15:35:42 | Preparing data and PHOTONAI objects for analysis...
# 07/12/2022-15:35:42 | Checking input data...
# 07/12/2022-15:35:42 | Running analysis with 442 samples.
#
# *****************************************************************************************************
# Outer Cross validation Fold 1
# *****************************************************************************************************
# 07/12/2022-15:35:42 | Preparing data for outer fold 1...
# 07/12/2022-15:35:42 | Preparing Hyperparameter Optimization...
# 07/12/2022-15:35:42 | Running Dummy Estimator...
# +---------------------+-----------+
# |  PERFORMANCE DUMMY  |           |
# +---------------------+-----------+
# |  mean_squared_error | 5188.6945 |
# | mean_absolute_error |  61.0798  |
# |  explained_variance |   0.0000  |
# +---------------------+-----------+
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:43 | Computed configuration 1/10 in 0:00:00.435464
# 07/12/2022-15:35:43 | Performance:             mean_squared_error - Train: 2.1611, Validation: 156350.0931
# 07/12/2022-15:35:43 | Best Performance So Far: mean_squared_error - Train: 2.1611, Validation: 156350.0931
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:43 | Computed configuration 2/10 in 0:00:00.594457
# 07/12/2022-15:35:43 | Performance:             mean_squared_error - Train: 2.1611, Validation: 156350.0931
# 07/12/2022-15:35:43 | Best Performance So Far: mean_squared_error - Train: 2.1611, Validation: 156350.0931
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:44 | Computed configuration 3/10 in 0:00:00.588894
# 07/12/2022-15:35:44 | Performance:             mean_squared_error - Train: 2.1611, Validation: 156350.0931
# 07/12/2022-15:35:44 | Best Performance So Far: mean_squared_error - Train: 2.1611, Validation: 156350.0931
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:45 | Computed configuration 4/10 in 0:00:00.659799
# 07/12/2022-15:35:45 | Performance:             mean_squared_error - Train: 2.1611, Validation: 156350.0931
# 07/12/2022-15:35:45 | Best Performance So Far: mean_squared_error - Train: 2.1611, Validation: 156350.0931
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:45 | Computed configuration 5/10 in 0:00:00.545928
# 07/12/2022-15:35:45 | Performance:             mean_squared_error - Train: 2.1611, Validation: 156350.0931
# 07/12/2022-15:35:45 | Best Performance So Far: mean_squared_error - Train: 2.1611, Validation: 156350.0931
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:46 | Computed configuration 6/10 in 0:00:00.631093
# 07/12/2022-15:35:46 | Performance:             mean_squared_error - Train: 2.1611, Validation: 156350.0931
# 07/12/2022-15:35:46 | Best Performance So Far: mean_squared_error - Train: 2.1611, Validation: 156350.0931
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:46 | Computed configuration 7/10 in 0:00:00.581210
# 07/12/2022-15:35:46 | Performance:             mean_squared_error - Train: 2.1611, Validation: 156350.0931
# 07/12/2022-15:35:46 | Best Performance So Far: mean_squared_error - Train: 2.1611, Validation: 156350.0931
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:47 | Computed configuration 8/10 in 0:00:00.702313
# 07/12/2022-15:35:47 | Performance:             mean_squared_error - Train: 2.1611, Validation: 156350.0931
# 07/12/2022-15:35:47 | Best Performance So Far: mean_squared_error - Train: 2.1611, Validation: 156350.0931
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:48 | Computed configuration 9/10 in 0:00:00.688001
# 07/12/2022-15:35:48 | Performance:             mean_squared_error - Train: 2.1611, Validation: 156350.0931
# 07/12/2022-15:35:48 | Best Performance So Far: mean_squared_error - Train: 2.1611, Validation: 156350.0931
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:48 | Computed configuration 10/10 in 0:00:00.708862
# 07/12/2022-15:35:48 | Performance:             mean_squared_error - Train: 2.1611, Validation: 156350.0931
# 07/12/2022-15:35:48 | Best Performance So Far: mean_squared_error - Train: 2.1611, Validation: 156350.0931
# -----------------------------------------------------------------------------------------------------
# 07/12/2022-15:35:48 | Hyperparameter Optimization finished. Now finding best configuration ....
# 07/12/2022-15:35:48 | 10
# -----------------------------------------------------------------------------------------------------
# BEST_CONFIG
# -----------------------------------------------------------------------------------------------------
# {}
# -----------------------------------------------------------------------------------------------------
# VALIDATION PERFORMANCE
# -----------------------------------------------------------------------------------------------------
# +---------------------+-------------------+------------------+
# |        METRIC       | PERFORMANCE TRAIN | PERFORMANCE TEST |
# +---------------------+-------------------+------------------+
# |  mean_squared_error |       2.1611      |   156350.0931    |
# | mean_absolute_error |       0.6891      |     229.6639     |
# |  explained_variance |       0.9997      |     -25.8589     |
# +---------------------+-------------------+------------------+
# 07/12/2022-15:35:49 | Calculating best model performance on test set...
# -----------------------------------------------------------------------------------------------------
# TEST PERFORMANCE
# -----------------------------------------------------------------------------------------------------
# +---------------------+-------------------+------------------+
# |        METRIC       | PERFORMANCE TRAIN | PERFORMANCE TEST |
# +---------------------+-------------------+------------------+
# |  mean_squared_error |      46.5713      |    84768.9598    |
# | mean_absolute_error |       3.6071      |     185.1793     |
# |  explained_variance |       0.9926      |     -15.4970     |
# +---------------------+-------------------+------------------+
# 07/12/2022-15:35:49 | Computations in outer fold 1 took 0.10788321666666666 minutes.
# 07/12/2022-15:35:49 | Writing results to project folder...
#
# *****************************************************************************************************
# Outer Cross validation Fold 2
# *****************************************************************************************************
# 07/12/2022-15:35:49 | Preparing data for outer fold 2...
# 07/12/2022-15:35:49 | Preparing Hyperparameter Optimization...
# 07/12/2022-15:35:49 | Running Dummy Estimator...
# +---------------------+-----------+
# |  PERFORMANCE DUMMY  |           |
# +---------------------+-----------+
# |  mean_squared_error | 6851.9419 |
# | mean_absolute_error |  71.2750  |
# |  explained_variance |   0.0000  |
# +---------------------+-----------+
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:49 | Computed configuration 1/10 in 0:00:00.602934
# 07/12/2022-15:35:49 | Performance:             mean_squared_error - Train: 0.6857, Validation: 73219.2044
# 07/12/2022-15:35:49 | Best Performance So Far: mean_squared_error - Train: 0.6857, Validation: 73219.2044
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:50 | Computed configuration 2/10 in 0:00:00.624950
# 07/12/2022-15:35:50 | Performance:             mean_squared_error - Train: 0.6857, Validation: 73219.2044
# 07/12/2022-15:35:50 | Best Performance So Far: mean_squared_error - Train: 0.6857, Validation: 73219.2044
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:51 | Computed configuration 3/10 in 0:00:00.602438
# 07/12/2022-15:35:51 | Performance:             mean_squared_error - Train: 0.6857, Validation: 73219.2044
# 07/12/2022-15:35:51 | Best Performance So Far: mean_squared_error - Train: 0.6857, Validation: 73219.2044
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:51 | Computed configuration 4/10 in 0:00:00.460285
# 07/12/2022-15:35:51 | Performance:             mean_squared_error - Train: 0.6857, Validation: 73219.2044
# 07/12/2022-15:35:51 | Best Performance So Far: mean_squared_error - Train: 0.6857, Validation: 73219.2044
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:52 | Computed configuration 5/10 in 0:00:00.579341
# 07/12/2022-15:35:52 | Performance:             mean_squared_error - Train: 0.6857, Validation: 73219.2044
# 07/12/2022-15:35:52 | Best Performance So Far: mean_squared_error - Train: 0.6857, Validation: 73219.2044
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:52 | Computed configuration 6/10 in 0:00:00.652720
# 07/12/2022-15:35:52 | Performance:             mean_squared_error - Train: 0.6857, Validation: 73219.2044
# 07/12/2022-15:35:52 | Best Performance So Far: mean_squared_error - Train: 0.6857, Validation: 73219.2044
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:53 | Computed configuration 7/10 in 0:00:00.694591
# 07/12/2022-15:35:53 | Performance:             mean_squared_error - Train: 0.6857, Validation: 73219.2044
# 07/12/2022-15:35:53 | Best Performance So Far: mean_squared_error - Train: 0.6857, Validation: 73219.2044
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:54 | Computed configuration 8/10 in 0:00:00.521135
# 07/12/2022-15:35:54 | Performance:             mean_squared_error - Train: 0.6857, Validation: 73219.2044
# 07/12/2022-15:35:54 | Best Performance So Far: mean_squared_error - Train: 0.6857, Validation: 73219.2044
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:54 | Computed configuration 9/10 in 0:00:00.604196
# 07/12/2022-15:35:54 | Performance:             mean_squared_error - Train: 0.6857, Validation: 73219.2044
# 07/12/2022-15:35:54 | Best Performance So Far: mean_squared_error - Train: 0.6857, Validation: 73219.2044
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:55 | Computed configuration 10/10 in 0:00:00.682970
# 07/12/2022-15:35:55 | Performance:             mean_squared_error - Train: 0.6857, Validation: 73219.2044
# 07/12/2022-15:35:55 | Best Performance So Far: mean_squared_error - Train: 0.6857, Validation: 73219.2044
# -----------------------------------------------------------------------------------------------------
# 07/12/2022-15:35:55 | Hyperparameter Optimization finished. Now finding best configuration ....
# 07/12/2022-15:35:55 | 10
# -----------------------------------------------------------------------------------------------------
# BEST_CONFIG
# -----------------------------------------------------------------------------------------------------
# {}
# -----------------------------------------------------------------------------------------------------
# VALIDATION PERFORMANCE
# -----------------------------------------------------------------------------------------------------
# +---------------------+-------------------+------------------+
# |        METRIC       | PERFORMANCE TRAIN | PERFORMANCE TEST |
# +---------------------+-------------------+------------------+
# |  mean_squared_error |       0.6857      |    73219.2044    |
# | mean_absolute_error |       0.4726      |     176.0764     |
# |  explained_variance |       0.9999      |     -12.0132     |
# +---------------------+-------------------+------------------+
# 07/12/2022-15:35:55 | Calculating best model performance on test set...
# -----------------------------------------------------------------------------------------------------
# TEST PERFORMANCE
# -----------------------------------------------------------------------------------------------------
# +---------------------+-------------------+------------------+
# |        METRIC       | PERFORMANCE TRAIN | PERFORMANCE TEST |
# +---------------------+-------------------+------------------+
# |  mean_squared_error |      20.2159      |    58028.2933    |
# | mean_absolute_error |       2.7519      |     163.6631     |
# |  explained_variance |       0.9963      |     -7.5197      |
# +---------------------+-------------------+------------------+
# 07/12/2022-15:35:55 | Computations in outer fold 2 took 0.10529808333333333 minutes.
# 07/12/2022-15:35:55 | Writing results to project folder...
#
# *****************************************************************************************************
# Outer Cross validation Fold 3
# *****************************************************************************************************
# 07/12/2022-15:35:55 | Preparing data for outer fold 3...
# 07/12/2022-15:35:55 | Preparing Hyperparameter Optimization...
# 07/12/2022-15:35:55 | Running Dummy Estimator...
# +---------------------+-----------+
# |  PERFORMANCE DUMMY  |           |
# +---------------------+-----------+
# |  mean_squared_error | 5856.5599 |
# | mean_absolute_error |  65.4854  |
# |  explained_variance |   0.0000  |
# +---------------------+-----------+
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:56 | Computed configuration 1/10 in 0:00:00.397687
# 07/12/2022-15:35:56 | Performance:             mean_squared_error - Train: 0.6811, Validation: 77763.7368
# 07/12/2022-15:35:56 | Best Performance So Far: mean_squared_error - Train: 0.6811, Validation: 77763.7368
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:56 | Computed configuration 2/10 in 0:00:00.433491
# 07/12/2022-15:35:56 | Performance:             mean_squared_error - Train: 0.6811, Validation: 77763.7368
# 07/12/2022-15:35:56 | Best Performance So Far: mean_squared_error - Train: 0.6811, Validation: 77763.7368
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:57 | Computed configuration 3/10 in 0:00:00.671704
# 07/12/2022-15:35:57 | Performance:             mean_squared_error - Train: 0.6811, Validation: 77763.7368
# 07/12/2022-15:35:57 | Best Performance So Far: mean_squared_error - Train: 0.6811, Validation: 77763.7368
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:57 | Computed configuration 4/10 in 0:00:00.608008
# 07/12/2022-15:35:57 | Performance:             mean_squared_error - Train: 0.6811, Validation: 77763.7368
# 07/12/2022-15:35:57 | Best Performance So Far: mean_squared_error - Train: 0.6811, Validation: 77763.7368
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:58 | Computed configuration 5/10 in 0:00:00.678048
# 07/12/2022-15:35:58 | Performance:             mean_squared_error - Train: 0.6811, Validation: 77763.7368
# 07/12/2022-15:35:58 | Best Performance So Far: mean_squared_error - Train: 0.6811, Validation: 77763.7368
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:59 | Computed configuration 6/10 in 0:00:00.586792
# 07/12/2022-15:35:59 | Performance:             mean_squared_error - Train: 0.6811, Validation: 77763.7368
# 07/12/2022-15:35:59 | Best Performance So Far: mean_squared_error - Train: 0.6811, Validation: 77763.7368
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:35:59 | Computed configuration 7/10 in 0:00:00.673223
# 07/12/2022-15:35:59 | Performance:             mean_squared_error - Train: 0.6811, Validation: 77763.7368
# 07/12/2022-15:35:59 | Best Performance So Far: mean_squared_error - Train: 0.6811, Validation: 77763.7368
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:36:00 | Computed configuration 8/10 in 0:00:00.662218
# 07/12/2022-15:36:00 | Performance:             mean_squared_error - Train: 0.6811, Validation: 77763.7368
# 07/12/2022-15:36:00 | Best Performance So Far: mean_squared_error - Train: 0.6811, Validation: 77763.7368
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:36:01 | Computed configuration 9/10 in 0:00:00.658967
# 07/12/2022-15:36:01 | Performance:             mean_squared_error - Train: 0.6811, Validation: 77763.7368
# 07/12/2022-15:36:01 | Best Performance So Far: mean_squared_error - Train: 0.6811, Validation: 77763.7368
# -----------------------------------------------------------------------------------------------------
# {}
# {}
# {}
# 07/12/2022-15:36:01 | Computed configuration 10/10 in 0:00:00.690731
# 07/12/2022-15:36:01 | Performance:             mean_squared_error - Train: 0.6811, Validation: 77763.7368
# 07/12/2022-15:36:01 | Best Performance So Far: mean_squared_error - Train: 0.6811, Validation: 77763.7368
# -----------------------------------------------------------------------------------------------------
# 07/12/2022-15:36:01 | Hyperparameter Optimization finished. Now finding best configuration ....
# 07/12/2022-15:36:01 | 10
# -----------------------------------------------------------------------------------------------------
# BEST_CONFIG
# -----------------------------------------------------------------------------------------------------
# {}
# -----------------------------------------------------------------------------------------------------
# VALIDATION PERFORMANCE
# -----------------------------------------------------------------------------------------------------
# +---------------------+-------------------+------------------+
# |        METRIC       | PERFORMANCE TRAIN | PERFORMANCE TEST |
# +---------------------+-------------------+------------------+
# |  mean_squared_error |       0.6811      |    77763.7368    |
# | mean_absolute_error |       0.5125      |     199.3900     |
# |  explained_variance |       0.9999      |     -11.9317     |
# +---------------------+-------------------+------------------+
# 07/12/2022-15:36:01 | Calculating best model performance on test set...
# -----------------------------------------------------------------------------------------------------
# TEST PERFORMANCE
# -----------------------------------------------------------------------------------------------------
# +---------------------+-------------------+------------------+
# |        METRIC       | PERFORMANCE TRAIN | PERFORMANCE TEST |
# +---------------------+-------------------+------------------+
# |  mean_squared_error |      30.9570      |    81583.7632    |
# | mean_absolute_error |       3.4736      |     186.6244     |
# |  explained_variance |       0.9948      |     -12.9412     |
# +---------------------+-------------------+------------------+
# 07/12/2022-15:36:02 | Computations in outer fold 3 took 0.10655693333333334 minutes.
# 07/12/2022-15:36:02 | Writing results to project folder...
#
# *****************************************************************************************************
# Finished all outer fold computations.
# 07/12/2022-15:36:02 | Now analysing the final results...
# 07/12/2022-15:36:02 | Computing dummy metrics...
# 07/12/2022-15:36:02 | Computing mean and std for all outer fold metrics...
# 07/12/2022-15:36:02 | Find best config across outer folds...
# 07/12/2022-15:36:02 | Save final results...
# 07/12/2022-15:36:02 | Writing results to project folder...
# 07/12/2022-15:36:02 | Prepare Hyperpipe.optimum pipe with best config..
# 07/12/2022-15:36:02 | Fitting best model...
# 07/12/2022-15:36:02 | Saved best model to file.
# 07/12/2022-15:36:02 | Mapping back feature importances...
# 07/12/2022-15:36:02 | No feature importances available for ConformalRegressor!
# 07/12/2022-15:36:02 | Summarizing results...
# 07/12/2022-15:36:02 | Write predictions to files...
# 07/12/2022-15:36:02 | Write summary...
# *****************************************************************************************************
#
# ANALYSIS INFORMATION ================================================================================
# Project Folder: ./tmp/conformal_pipe_results_2022-12-07_15-35-42,
# Computation Time: 2022-12-07 15:35:42.799394 - 2022-12-07 15:36:02.197376
# Duration: 0:00:19.397982
# Optimized for: mean_squared_error
# Hyperparameter Optimizer: random_search
#
# DUMMY RESULTS =======================================================================================
# +---------------------+-----------+
# |  PERFORMANCE DUMMY  |           |
# +---------------------+-----------+
# |  mean_squared_error | 5965.7321 |
# | mean_absolute_error |  65.9468  |
# |  explained_variance |   0.0000  |
# +---------------------+-----------+
#
# AVERAGE PERFORMANCE ACROSS OUTER FOLDS ==============================================================
# +---------------------+---------------+--------------+--------------+--------------+
# |     Metric Name     | Training Mean | Training Std |  Test Mean   |   Test Std   |
# +---------------------+---------------+--------------+--------------+--------------+
# |  mean_squared_error |    32.58137   |  10.820687   | 74793.672077 | 11926.016754 |
# | mean_absolute_error |    3.277558   |   0.375678   |  178.488912  |  10.500037   |
# |  explained_variance |    0.994586   |   0.001509   |  -11.985947  |   3.326028   |
# +---------------------+---------------+--------------+--------------+--------------+
#
# BEST HYPERPARAMETER CONFIGURATION ===================================================================
# {}
#
#
# +--------+--------------------+---------------------+--------------------+----------------------------+
# | fold # | mean_squared_error | mean_absolute_error | explained_variance | Best Hyperparameter Config |
# +--------+--------------------+---------------------+--------------------+----------------------------+
# |   1    |     84768.9598     |       185.1793      |      -15.4970      |             {}             |
# |   2*   |     58028.2933     |       163.6631      |      -7.5197       |             {}             |
# |   3    |     81583.7632     |       186.6244      |      -12.9412      |             {}             |
# +--------+--------------------+---------------------+--------------------+----------------------------+
#
# PHOTONAI 2.2.1 ======================================================================================
# Your results are stored in ./tmp/conformal_pipe_results_2022-12-07_15-35-42
# Go to https://explorer.photon-ai.com and upload your photon_result_file.json for convenient result visualization!
# For more info and documentation visit https://www.photon-ai.com
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.conda/envs/photonai_conformal/lib/python3.10/site-packages/IPython/core/formatters.py:972, in MimeBundleFormatter.__call__(self, obj, include, exclude)
#     969     method = get_real_method(obj, self.print_method)
#     971     if method is not None:
# --> 972         return method(include=include, exclude=exclude)
#     973     return None
#     974 else:
#
# File ~/.conda/envs/photonai_conformal/lib/python3.10/site-packages/sklearn/base.py:631, in BaseEstimator._repr_mimebundle_(self, **kwargs)
#     629 output = {"text/plain": repr(self)}
#     630 if get_config()["display"] == "diagram":
# --> 631     output["text/html"] = estimator_html_repr(self)
#     632 return output
#
# File ~/.conda/envs/photonai_conformal/lib/python3.10/site-packages/sklearn/utils/_estimator_html_repr.py:417, in estimator_html_repr(estimator)
#     403 fallback_msg = (
#     404     "In a Jupyter environment, please rerun this cell to show the HTML"
#     405     " representation or trust the notebook. <br />On GitHub, the"
#     406     " HTML representation is unable to render, please try loading this page"
#     407     " with nbviewer.org."
#     408 )
#     409 out.write(
#     410     f"<style>{style_with_id}</style>"
#     411     f'<div id="{container_id}" class="sk-top-container">'
#    (...)
#     415     '<div class="sk-container" hidden>'
#     416 )
# --> 417 _write_estimator_html(
#     418     out,
#     419     estimator,
#     420     estimator.__class__.__name__,
#     421     estimator_str,
#     422     first_call=True,
#     423 )
#     424 out.write("</div></div>")
#     426 html_output = out.getvalue()
#
# File ~/.conda/envs/photonai_conformal/lib/python3.10/site-packages/sklearn/utils/_estimator_html_repr.py:151, in _write_estimator_html(out, estimator, estimator_label, estimator_label_details, first_call)
#     149 """Write estimator to html in serial, parallel, or by itself (single)."""
#     150 if first_call:
# --> 151     est_block = _get_visual_block(estimator)
#     152 else:
#     153     with config_context(print_changed_only=True):
#
# File ~/.conda/envs/photonai_conformal/lib/python3.10/site-packages/sklearn/utils/_estimator_html_repr.py:127, in _get_visual_block(estimator)
#     123 # check if estimator looks like a meta estimator wraps estimators
#     124 if hasattr(estimator, "get_params"):
#     125     estimators = [
#     126         (key, est)
# --> 127         for key, est in estimator.get_params(deep=False).items()
#     128         if hasattr(est, "get_params") and hasattr(est, "fit")
#     129     ]
#     130     if estimators:
#     131         return _VisualBlock(
#     132             "parallel",
#     133             [est for _, est in estimators],
#     134             names=[f"{key}: {est.__class__.__name__}" for key, est in estimators],
#     135             name_details=[str(est) for _, est in estimators],
#     136         )
#
# File ~/.conda/envs/photonai_conformal/lib/python3.10/site-packages/sklearn/base.py:211, in BaseEstimator.get_params(self, deep)
#     209 out = dict()
#     210 for key in self._get_param_names():
# --> 211     value = getattr(self, key)
#     212     if deep and hasattr(value, "get_params") and not isinstance(value, type):
#     213         deep_items = value.get_params().items()
#
# AttributeError: 'Hyperpipe' object has no attribute 'best_config_metric'
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File ~/.conda/envs/photonai_conformal/lib/python3.10/site-packages/IPython/core/formatters.py:342, in BaseFormatter.__call__(self, obj)
#     340     method = get_real_method(obj, self.print_method)
#     341     if method is not None:
# --> 342         return method()
#     343     return None
#     344 else:
#
# File ~/.conda/envs/photonai_conformal/lib/python3.10/site-packages/sklearn/base.py:625, in BaseEstimator._repr_html_inner(self)
#     620 def _repr_html_inner(self):
#     621     """This function is returned by the @property `_repr_html_` to make
#     622     `hasattr(estimator, "_repr_html_") return `True` or `False` depending
#     623     on `get_config()["display"]`.
#     624     """
# --> 625     return estimator_html_repr(self)
#
# File ~/.conda/envs/photonai_conformal/lib/python3.10/site-packages/sklearn/utils/_estimator_html_repr.py:417, in estimator_html_repr(estimator)
#     403 fallback_msg = (
#     404     "In a Jupyter environment, please rerun this cell to show the HTML"
#     405     " representation or trust the notebook. <br />On GitHub, the"
#     406     " HTML representation is unable to render, please try loading this page"
#     407     " with nbviewer.org."
#     408 )
#     409 out.write(
#     410     f"<style>{style_with_id}</style>"
#     411     f'<div id="{container_id}" class="sk-top-container">'
#    (...)
#     415     '<div class="sk-container" hidden>'
#     416 )
# --> 417 _write_estimator_html(
#     418     out,
#     419     estimator,
#     420     estimator.__class__.__name__,
#     421     estimator_str,
#     422     first_call=True,
#     423 )
#     424 out.write("</div></div>")
#     426 html_output = out.getvalue()
#
# File ~/.conda/envs/photonai_conformal/lib/python3.10/site-packages/sklearn/utils/_estimator_html_repr.py:151, in _write_estimator_html(out, estimator, estimator_label, estimator_label_details, first_call)
#     149 """Write estimator to html in serial, parallel, or by itself (single)."""
#     150 if first_call:
# --> 151     est_block = _get_visual_block(estimator)
#     152 else:
#     153     with config_context(print_changed_only=True):
#
# File ~/.conda/envs/photonai_conformal/lib/python3.10/site-packages/sklearn/utils/_estimator_html_repr.py:127, in _get_visual_block(estimator)
#     123 # check if estimator looks like a meta estimator wraps estimators
#     124 if hasattr(estimator, "get_params"):
#     125     estimators = [
#     126         (key, est)
# --> 127         for key, est in estimator.get_params(deep=False).items()
#     128         if hasattr(est, "get_params") and hasattr(est, "fit")
#     129     ]
#     130     if estimators:
#     131         return _VisualBlock(
#     132             "parallel",
#     133             [est for _, est in estimators],
#     134             names=[f"{key}: {est.__class__.__name__}" for key, est in estimators],
#     135             name_details=[str(est) for _, est in estimators],
#     136         )
#
# File ~/.conda/envs/photonai_conformal/lib/python3.10/site-packages/sklearn/base.py:211, in BaseEstimator.get_params(self, deep)
#     209 out = dict()
#     210 for key in self._get_param_names():
# --> 211     value = getattr(self, key)
#     212     if deep and hasattr(value, "get_params") and not isinstance(value, type):
#     213         deep_items = value.get_params().items()
#
# AttributeError: 'Hyperpipe' object has no attribute 'best_config_metric'
# Hyperpipe(name='conformal_pipe')
